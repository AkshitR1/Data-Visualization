# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('universal_top_spotify_songs.csv')

df

df
# Out:
#                     spotify_id                               name  \
# 0       5N3hjp1WNayUPZrA8kJmJP               Please Please Please
# 1       2qSkIjg1o9h3YT9RAgYN75                           Espresso
# 2       6dOtVTDdiauQNBQEDOtlAB                 BIRDS OF A FEATHER
# 3       6XjDF6nds4DE2BBbagZol6                          Gata Only
# 4       6AI3ezQ4o3HUoP6Dhudph3                        Not Like Us
# ...                        ...                                ...
# 934948  0AYt6NMyyLd0rLuvr0UkMH          Slime You Out (feat. SZA)
# 934949  2Gk6fi0dqt91NKvlzGsmm7  SAY MY GRACE (feat. Travis Scott)
# 934950  26b3oVLrRUaaybJulow9kz                             People
# 934951  5ydjxBSUIDn26MFzU3asP4                         Rainy Days
# 934952  59NraMJsLaMCVtwXTSia8i                              Prada
#
#                             artists  daily_rank  daily_movement  \
# 0                 Sabrina Carpenter           1               1
# ...

# %%
dk = df.drop('spotify_id', axis=1)

dk = dk.set_index('daily_rank')

top50 = dk.head(50)

# %%
sns.scatterplot(x='loudness', y='popularity', data=top50, hue='tempo', palette='rocket')
plt.title('Loudness vs Popularity  ')
plt.show()

# %%
ds1 = df.drop('spotify_id', axis=1)

ds1 = ds1.set_index('daily_rank')

top10  = ds1.head(10)
top20 = ds1.head(20)

top40 = ds1.head(40)

top1000 = ds1.head(1000)

top100 = ds1.head(100)

# %%
plt.figure(figsize=(12, 7))
sns.scatterplot(data = top1000, x='popularity', y='danceability',hue='weekly_movement',palette='husl')
plt.show()

# %%
ds1.columns
# Out:
# Index(['name', 'artists', 'daily_movement', 'weekly_movement', 'country',
#        'snapshot_date', 'popularity', 'is_explicit', 'duration_min',
#        'album_name', 'album_release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 7))
sns.scatterplot(data = top10, x='name', y='speechiness',hue='popularity',palette='husl')
plt.show()

# %%
df.isnull().sum()
# Out:
# spotify_id                0
# name                     27
# artists                  27
# daily_rank                0
# daily_movement            0
# weekly_movement           0
# country               12657
# snapshot_date             0
# popularity                0
# is_explicit               0
# duration_ms               0
# album_name              420
# album_release_date      339
# danceability              0
# energy                    0
# key                       0
# loudness                  0
# mode                      0
# speechiness               0
# acousticness              0
# instrumentalness          0
# liveness                  0
# valence                   0
# tempo                     0
# time_signature            0
# dtype: int64
